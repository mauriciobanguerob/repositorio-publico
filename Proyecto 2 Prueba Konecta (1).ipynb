# %% [markdown]
# ## PRUEBA TECNICA  ANALISTA 2 BA 2019 FRAUDE

# %% [markdown]
# #### Se cuenta con los datos de las ventas y los impuestos, se requiere explorar los datos y la elaboración de un modelo de predicción de los impuestos en función de las ventas obtenidas.

# %% [markdown]
# #### Accediendo a los datos.

# %%
# Importando la libreria.
import pandas as pd

# %%
# Directorio 
pwd
# Out:
# '/mnt/c'

# %%
# Acceso a los datos
df = pd.read_csv('bd regresion lineal.csv', sep=';',header = 0)
df.head()
# Out:
#    Precio de venta/1000  impuestos (local, escolar, condado)/1000
# 0                  25.9                                    49.176
# 1                  29.5                                    50.208
# 2                  27.9                                    45.429
# 3                  25.9                                    45.573
# 4                  29.9                                    50.597

# %% [markdown]
# #### Explorando los datos.

# %%
# Importando libreria
import numpy as np
import matplotlib.pyplot as plt

# %%
# Diagrama de dispersión
plt.scatter(df['impuestos (local, escolar, condado)/1000'],df['Precio de venta/1000'], alpha=0.5)
